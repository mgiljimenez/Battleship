# %% [markdown]
# #### Poner bonita y recta esa matriz
#
# [[' ' ' ' ' ' '🚣' ' ' ' ' ' ' '🛳' '🛳' '🛳']
#  [' ' ' ' ' ' '🚢' '🚢' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' '🚢' ' ' ' ']
#  [' ' ' ' '🚢' '🚢' ' ' ' ' ' ' '🚢' ' ' ' ']
#  [' ' '🚤' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' '🚤' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' '🚤' ' ' ' ' ' ' ' ' '🚣' ' ' ' ' ' ']
#  ['🚣' '🚤' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' '🛳' '🛳' '🛳' ' ' ' ' ' ' ' ' ' ']
#  [' ' '🚣' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']]

# %%
import numpy as np
from tabulate import tabulate
import pandas as pd

TAM_TABLERO = 10
TAM_BARCOS = [1, 1, 1, 1, 2, 2, 2, 3, 3, 4]
EMOJIS = {1: "🚣", 2: "🚢", 3: "🛳️", 4: "🚤"}



def generar_tablero(tablero_input):
    '''
    Esta función es la encargada de generar los tableros y de posicionar los barcos en ellos.
    '''
    # Diccionario que relaciona un número entero (que representa el tamaño de un barco) con un emoji correspondiente
    barcos = []
    for tam_barco in TAM_BARCOS:
        colocado = False
        while not colocado:
            fila, col = np.random.randint(TAM_TABLERO), np.random.randint(TAM_TABLERO)
            direccion = np.random.choice(['arriba', 'abajo', 'izquierda', 'derecha'])
            if direccion == 'arriba':
                posiciones = [(fila-i, col) for i in range(tam_barco)]
            elif direccion == 'abajo':
                posiciones = [(fila+i, col) for i in range(tam_barco)]
            elif direccion == 'izquierda':
                posiciones = [(fila, col-i) for i in range(tam_barco)]
            else:
                posiciones = [(fila, col+i) for i in range(tam_barco)]
            if all(0<=fila<TAM_TABLERO and 0<=col<TAM_TABLERO and tablero_input[fila, col]==" " for fila, col in posiciones):
                barco = {"tam": tam_barco, "posiciones": posiciones}
                barcos.append(barco)
                for fila, col in posiciones:
                    tablero_input[fila, col] = EMOJIS[tam_barco]
                colocado = True
    
    return tablero_input

tablero_jugador = generar_tablero(np.full((TAM_TABLERO, TAM_TABLERO), " "))
tablero_maquina = generar_tablero(np.full((TAM_TABLERO, TAM_TABLERO), " "))

# %% [markdown]
# ### Estética de la tabla usando una función

# %%
def estilo_celda(valor):
    if valor.strip() == "":
        return "background-color: lightgray"
    elif valor.isnumeric():
        return "background-color: lightblue"
    else:
        return ""

estilo = df_jugador.style.applymap(estilo_celda).set_properties(**{'font-size': '20px', 'text-align': 'center'})

display(estilo)
# Out:
# <style type="text/css">
# #T_d3825_row0_col0, #T_d3825_row0_col1, #T_d3825_row0_col2, #T_d3825_row0_col3, #T_d3825_row0_col4, #T_d3825_row0_col5, #T_d3825_row0_col7, #T_d3825_row0_col8, #T_d3825_row0_col9, #T_d3825_row1_col2, #T_d3825_row1_col3, #T_d3825_row1_col4, #T_d3825_row1_col5, #T_d3825_row1_col6, #T_d3825_row1_col7, #T_d3825_row1_col9, #T_d3825_row2_col0, #T_d3825_row2_col1, #T_d3825_row2_col2, #T_d3825_row2_col3, #T_d3825_row2_col6, #T_d3825_row2_col8, #T_d3825_row2_col9, #T_d3825_row3_col0, #T_d3825_row3_col1, #T_d3825_row3_col2, #T_d3825_row3_col3, #T_d3825_row3_col5, #T_d3825_row3_col6, #T_d3825_row4_col0, #T_d3825_row4_col1, #T_d3825_row4_col2, #T_d3825_row4_col3, #T_d3825_row4_col5, #T_d3825_row4_col6, #T_d3825_row4_col8, #T_d3825_row4_col9, #T_d3825_row5_col0, #T_d3825_row5_col1, #T_d3825_row5_col2, #T_d3825_row5_col3, #T_d3825_row5_col5, #T_d3825_row5_col6, #T_d3825_row5_col7, #T_d3825_row5_col8, #T_d3825_row5_col9, #T_d3825_row6_col0, #T_d3825_row6_col1, #T_d3825_row6_col2, #T_d3825_row6_col3, #T_d3825_row6_col6, #T_d3825_row7_col0, #T_d3825_row7_col1, #T_d3825_row7_col2, #T_d3825_row7_col3, #T_d3825_row7_col4, #T_d3825_row7_col5, #T_d3825_row7_col6, #T_d3825_row7_col7, #T_d3825_row7_col8, #T_d3825_row7_col9, #T_d3825_row8_col0, #T_d3825_row8_col1, #T_d3825_row8_col2, #T_d3825_row8_col3, #T_d3825_row8_col4, #T_d3825_row8_col5, #T_d3825_row8_col6, #T_d3825_row8_col8, #T_d3825_row8_col9, #T_d3825_row9_col0, #T_d3825_row9_col1, #T_d3825_row9_col2, #T_d3825_row9_col3, #T_d3825_row9_col4, #T_d3825_row9_col5, #T_d3825_row9_col6, #T_d3825_row9_col7, #T_d3825_row9_col8, #T_d3825_row9_col9 {
#   background-color: lightgray;
#   font-size: 20px;
#   text-align: center;
# }
# #T_d3825_row0_col6, #T_d3825_row1_col0, #T_d3825_row1_col1, #T_d3825_row1_col8, #T_d3825_row2_col4, #T_d3825_row2_col5, #T_d3825_row2_col7, #T_d3825_row3_col4, #T_d3825_row3_col7, #T_d3825_row3_col8, #T_d3825_row3_col9, #T_d3825_row4_col4, #T_d3825_row4_col7, #T_d3825_row5_col4, #T_d3825_row6_col4, #T_d3825_row6_col5, #T_d3825_row6_col7, #T_d3825_row6_col8, #T_d3825_row6_col9, #T_d3825_row8_col7 {
#   font-size: 20px;
#   text-align: center;
# }
# </style>
# <table id="T_d3825_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3825_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3825_row0_col0" class="data row0 col0" > </td>
#       <td id="T_d3825_row0_col1" class="data row0 col1" > </td>
#       <td id="T_d3825_row0_col2" class="data row0 col2" > </td>
#       <td id="T_d3825_row0_col3" class="data row0 col3" > </td>
#       <td id="T_d3825_row0_col4" class="data row0 col4" > </td>
#       <td id="T_d3825_row0_col5" class="data row0 col5" > </td>
#       <td id="T_d3825_row0_col6" class="data row0 col6" >🚣</td>
#       <td id="T_d3825_row0_col7" class="data row0 col7" > </td>
#       <td id="T_d3825_row0_col8" class="data row0 col8" > </td>
#       <td id="T_d3825_row0_col9" class="data row0 col9" > </td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3825_row1_col0" class="data row1 col0" >🚢</td>
#       <td id="T_d3825_row1_col1" class="data row1 col1" >🚢</td>
#       <td id="T_d3825_row1_col2" class="data row1 col2" > </td>
#       <td id="T_d3825_row1_col3" class="data row1 col3" > </td>
#       <td id="T_d3825_row1_col4" class="data row1 col4" > </td>
#       <td id="T_d3825_row1_col5" class="data row1 col5" > </td>
#       <td id="T_d3825_row1_col6" class="data row1 col6" > </td>
#       <td id="T_d3825_row1_col7" class="data row1 col7" > </td>
#       <td id="T_d3825_row1_col8" class="data row1 col8" >🚣</td>
#       <td id="T_d3825_row1_col9" class="data row1 col9" > </td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3825_row2_col0" class="data row2 col0" > </td>
#       <td id="T_d3825_row2_col1" class="data row2 col1" > </td>
#       <td id="T_d3825_row2_col2" class="data row2 col2" > </td>
#       <td id="T_d3825_row2_col3" class="data row2 col3" > </td>
#       <td id="T_d3825_row2_col4" class="data row2 col4" >🚤</td>
#       <td id="T_d3825_row2_col5" class="data row2 col5" >🚣</td>
#       <td id="T_d3825_row2_col6" class="data row2 col6" > </td>
#       <td id="T_d3825_row2_col7" class="data row2 col7" >🛳</td>
#       <td id="T_d3825_row2_col8" class="data row2 col8" > </td>
#       <td id="T_d3825_row2_col9" class="data row2 col9" > </td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3825_row3_col0" class="data row3 col0" > </td>
#       <td id="T_d3825_row3_col1" class="data row3 col1" > </td>
#       <td id="T_d3825_row3_col2" class="data row3 col2" > </td>
#       <td id="T_d3825_row3_col3" class="data row3 col3" > </td>
#       <td id="T_d3825_row3_col4" class="data row3 col4" >🚤</td>
#       <td id="T_d3825_row3_col5" class="data row3 col5" > </td>
#       <td id="T_d3825_row3_col6" class="data row3 col6" > </td>
#       <td id="T_d3825_row3_col7" class="data row3 col7" >🛳</td>
#       <td id="T_d3825_row3_col8" class="data row3 col8" >🚢</td>
#       <td id="T_d3825_row3_col9" class="data row3 col9" >🚢</td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3825_row4_col0" class="data row4 col0" > </td>
#       <td id="T_d3825_row4_col1" class="data row4 col1" > </td>
#       <td id="T_d3825_row4_col2" class="data row4 col2" > </td>
#       <td id="T_d3825_row4_col3" class="data row4 col3" > </td>
#       <td id="T_d3825_row4_col4" class="data row4 col4" >🚤</td>
#       <td id="T_d3825_row4_col5" class="data row4 col5" > </td>
#       <td id="T_d3825_row4_col6" class="data row4 col6" > </td>
#       <td id="T_d3825_row4_col7" class="data row4 col7" >🛳</td>
#       <td id="T_d3825_row4_col8" class="data row4 col8" > </td>
#       <td id="T_d3825_row4_col9" class="data row4 col9" > </td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3825_row5_col0" class="data row5 col0" > </td>
#       <td id="T_d3825_row5_col1" class="data row5 col1" > </td>
#       <td id="T_d3825_row5_col2" class="data row5 col2" > </td>
#       <td id="T_d3825_row5_col3" class="data row5 col3" > </td>
#       <td id="T_d3825_row5_col4" class="data row5 col4" >🚤</td>
#       <td id="T_d3825_row5_col5" class="data row5 col5" > </td>
#       <td id="T_d3825_row5_col6" class="data row5 col6" > </td>
#       <td id="T_d3825_row5_col7" class="data row5 col7" > </td>
#       <td id="T_d3825_row5_col8" class="data row5 col8" > </td>
#       <td id="T_d3825_row5_col9" class="data row5 col9" > </td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d3825_row6_col0" class="data row6 col0" > </td>
#       <td id="T_d3825_row6_col1" class="data row6 col1" > </td>
#       <td id="T_d3825_row6_col2" class="data row6 col2" > </td>
#       <td id="T_d3825_row6_col3" class="data row6 col3" > </td>
#       <td id="T_d3825_row6_col4" class="data row6 col4" >🚢</td>
#       <td id="T_d3825_row6_col5" class="data row6 col5" >🚢</td>
#       <td id="T_d3825_row6_col6" class="data row6 col6" > </td>
#       <td id="T_d3825_row6_col7" class="data row6 col7" >🛳</td>
#       <td id="T_d3825_row6_col8" class="data row6 col8" >🛳</td>
#       <td id="T_d3825_row6_col9" class="data row6 col9" >🛳</td>
#     </tr>
#     <tr>
#       <th id="T_d3825_level0_row7" class="row_heading level0 row7" >7</th>
#       <td
